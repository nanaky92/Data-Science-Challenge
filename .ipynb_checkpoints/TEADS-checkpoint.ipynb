# %% [markdown]
# # Data science challenge

# %% [markdown]
# We are given the following dataset:

# %%
import pandas
df = pandas.read_csv("aft100k.csv")
print(df.head(10))
# Out:
#    creative_id user_operating_system       user_device  \
# 0       113521               Android             Phone
# 1       115340               Windows  PersonalComputer
# 2       113582               Android             Phone
# 3        97385               Windows  PersonalComputer
# 4       114821               Windows  PersonalComputer
# 5       113065               Android            Tablet
# 6       111414                   iOS             Phone
# 7       111414                   iOS             Phone
# 8       112705               Windows  PersonalComputer
# 9       113176                 macOS  PersonalComputer
#
#    average_seconds_played      cost  revenue
# 0                     NaN  0.010128      0.0
# 1                0.000000  0.005937      0.0
# 2                7.142857  0.004398      0.0
# 3                     NaN  0.006157      0.0
# 4                     NaN  0.001994      0.0
# 5                     NaN  0.003781      0.0
# 6               17.000000  0.002836      0.0
# 7                     NaN  0.002836      0.0
# 8               14.560606  0.006157      0.0
# 9                0.000000  0.006157      0.0

# %% [markdown]
# - creative_id: A unique identifier of the video that has been displayed to the user
# - user_operating_system: The user Operating System (OS)
# - user_device: The user device type
# - average_seconds_played: The average number of seconds the user usually watches our videos (only if we already know the user, based on the user history)
# - cost: The cost we had to pay to display the video
# - revenue: The revenue generated by this video when it has been watched

# %% [markdown]
# ## Preliminary questions
#
# ####  1) The margin being defined as (revenue - cost) / revenue, what is our global margin based on this log?

# %%
print("Are there null revenues? {}".format(df["revenue"].isnull().values.any()))
print("Are there null costs? {}".format(df["cost"].isnull().values.any()))
# Out:
# Are there null revenues? False
# Are there null costs? False

# %%
revs = df["revenue"].sum()
costs = df["cost"].sum()
margin = (revs-costs)/revs
print("Global margin is {0:.4f}, or {1:.2f}%".format(margin, margin*100))
# Out:
# Global margin is 0.2719, or 27.19%

# %% [markdown]
# #### 2) Can you think of other interesting metrics to optimize
#
# Metrics to optimize:
#
# 1) Profits - No explanation needed.
#
# 2) Profits per device - We want to make sure all devices are profitable.
#
# 3) Profits per OS - We want to make sure all OSs are profitable.
#
# 4) Profits per video - We want to make sure all ads are profitable.
#
# I would also like to understand why sometimes it takes more seconds than others to get the money - some of them don't make us any money in 30 seconds, some of them do in 10 seconds. I guess it is very possible that we are losing money in some type of ads. Maybe we should only display them in certain platforms where people is willing to spend more time watching ads - and this is a metric we could get from our csv, the number of seconds per device.
#
# Moreover, it may be important for our clients two traditional metrics that don't appear in the csv: Click-through rate (CTR) and Conversion rate.

# %% [markdown]
# #### 3) What are the most profitable Operating Systems?

# %%
df_agg = df[['user_operating_system','cost', 'revenue']].groupby(
    ['user_operating_system']).sum()
series_profits = df_agg["revenue"]-df_agg["cost"]
print("Most profitable OSs:")
display(series_profits.sort_values(ascending=False))
# Out:
# Most profitable OSs:
# user_operating_system
# iOS              115.521775
# Windows           65.873808
# Android           27.279364
# OS X               1.707775
# Chrome OS          0.428130
# Linux              0.372922
# macOS              0.248021
# Fire OS            0.142575
# unknown            0.093995
# BlackBerry OS      0.077391
# BSD                0.040430
# RIM OS            -0.005229
# dtype: float64

# %% [markdown]
# The only real profitability comes from iOS, Windows and Android - anything else is barely profitable.

# %% [markdown]
# ## Machine learning questions
#
# #### How would you use this historical data to predict the event 'we benefit from a revenue' (i.e. revenue > 0) in a dataset where the revenue is not known yet?
#
# #### Compute the prediction accuracy of a well chosen algorithm and comment the results. Do not hesitate to describe your methodology.

# %% [markdown]
# The problem at hand is a problem of supervised learning, in particular, it is a regression problem. We need to build a regressor from our dataset, using:
#
# - Five features: *creative_id, user_operating_system, user_device, average_seconds_played, cost*.
# - A label: *revenues*.
# - A regression algorithm: We have a dataset with 100 000 examples - that is pretty good to use some of the more complex algorithms like SVMs with kernels, or ensemble learning (random forests, adaboost). Neural networks could also be considered but, considering the scope of this work, it would take too long to train and optimize.
#
#
# In order to validate our results, we will divide the dataset in 2, training set (80%) and test set (20%). Cross validation with several bags would be a better technique, but it would take longer.
#
# Before doing this, and just in case our data has some hidden time sequentiality, let's shuffle the data.

# %%
from sklearn.utils import shuffle

df = shuffle(df)

df_train = df[:len(df)*4//5]
df_test = df[len(df)*4//5:]

# %% [markdown]
# ##### Feature Generation
#
# Feature generation is one of the most important processes in data science. A good result is accomplished thanks to domain expertise, proper data visualization, and trial and error - but this are in general too time consuming for the scope of the project.

# %% [markdown]
# Some interesting features we could investigate are:
#
# 1) Interactions: Interaction between the videos (creative_id) and the user device, or with the video and the operating system.
#
# 2) Binning: Create bins in case there is some skewness in a variable - for example, in our case, most of the distribution is close to the min.

# %% [markdown]
# ##### Data cleaning:
#
# The first problem we face is that the features user_device and average_seconds_played are not present in some examples of the data set - or, in pandas' jargon, they are NaNs.

# %%
feature_cols = ['creative_id', 'user_operating_system', 'user_device', 
                'average_seconds_played', 'cost']
label_col = ['revenue']

X_train = df_train.loc[:, feature_cols]
y_train = df_train[label_col]

print(X_train.isnull().sum())
print(y_train.isnull().sum())
# Out:
# creative_id                   0
# user_operating_system         0
# user_device                   7
# average_seconds_played    49478
# cost                          0
# dtype: int64
# revenue    0
# dtype: int64

# %% [markdown]
# In the case of *user_device*, it is not a big problem (only 8 labels out of 100 000, we can discard 8 without any second thoughts). Also substituting the NaNs for the average or something similar is tricky since this is a categorical feature (i.e., a string) - we could use the most frequent value but, again, there is no need.

# %%
y_train = y_train[-X_train["user_device"].isnull()]
X_train = X_train[-X_train["user_device"].isnull()]

# %% [markdown]
# In the case of *average_seconds_played*, the problem is different: more than half of the data does not contain a value for the feature. However in this case, this is a numerical feature which gives us two options:
#
# 1) Removal: We would end up with around 40% of the dataset. The impact of this could be huge, but at least we are not "tampering" the data.
#
# 2) Substituting the data with its average, mode or median. This looks more promising, and it will be our default approach.
#
# It could be interesting to compare the performances of both options, but for the scope of this work lets limit ourselves to the second option.

# %%
import numpy as np
from sklearn.preprocessing import Imputer

imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
X_train["average_seconds_played"] = imp.fit_transform(X_train[["average_seconds_played"]])

# %% [markdown]
# ##### Data visualization
#
# Here is some very basic information from the dataset.

# %%
X_train.describe()
# Out:
#          creative_id  average_seconds_played          cost
# count   79993.000000            79993.000000  79993.000000
# mean   112153.337630               10.570334      0.005666
# std      5262.945051                6.056164      0.003503
# min     50634.000000                0.000000      0.000473
# 25%    112181.000000               10.570334      0.003308
# 50%    113521.000000               10.570334      0.004837
# 75%    114948.000000               10.570334      0.006605
# max    115465.000000              175.000000      0.052878

# %% [markdown]
# Let's use some bar plots for the categorical features:

# %%
# %matplotlib inline

X_train["user_operating_system"].value_counts().plot(kind='bar', title='user_operating_system')

# %% [markdown]
# We can see that our sample is mostly with iOS and Windows, and also some Android.

# %%
# %matplotlib inline

X_train["user_device"].value_counts().plot(kind='bar', title='user_device')

# %% [markdown]
# We can appreciate that connected TVs are almost non existent.
#
# For the numerical features, we have the following:

# %%
# %matplotlib inline

X_train["average_seconds_played"].plot(kind='hist', title='average_seconds_played')

# %% [markdown]
# This calls for transformations. Let's try with a log transformation instead, with a logarithmic y-axis for better visualization.

# %%
# %matplotlib inline

X_train["average_seconds_played"] = pandas.Series(np.log1p(X_train["average_seconds_played"]))
X_train["average_seconds_played"].plot(kind='hist', logy=True, title='average_seconds_played')

# %% [markdown]
# This looks more like a normal distribution (actually, like a Laplace distribution due to its high kurtosis).
#
# For the cost, this is what the histogram looks like:

# %%
# %matplotlib inline

X_train["cost"].plot(kind='hist', logy=True, title='cost')

# %% [markdown]
# Again, this calls for transformations. The log transformation does not work well, but the boxcox does.

# %%
# %matplotlib inline

pandas.Series(np.log1p(X_train["cost"])).plot(kind='hist', logy=True, title='cost')

# %%
# %matplotlib inline

from scipy.stats import boxcox
boxcox, _ = boxcox(X_train["cost"])
boxcox = pandas.Series(boxcox)

boxcox.plot(kind='hist', logy=True, title='cost')

# %%
X_train["cost"] = boxcox.values

# %% [markdown]
# ##### Dealing with categorical features

# %% [markdown]
# We also need to encode the categorical features (*user_operating_system, user_device*) in order to feed them to the regressor algorithm. We could use CategoricalEncoder in order to do so, with "one hot" encoding being the preference here (since we don't want the ordering than the "ordinal" encoding brings).
#
# `from sklearn import preprocessing`
#
# `enc = preprocessing.CategoricalEncoder(encoding='onehot')`
#
# However, it is not implemented yet in the version we are using so we will have to do it manually.

# %%
def encode_categorical_feature(feature_name, df):
    index_list = df[feature_name].value_counts().axes[0].tolist()
    for index_elem in index_list:
        new_feature_name = "{} {}".format(feature_name, index_elem)
        df[new_feature_name] = df[feature_name]==index_elem
    
    return df.drop(feature_name, axis=1)


X_train = encode_categorical_feature("user_operating_system", X_train)
X_train = encode_categorical_feature("user_device", X_train)

X_train
# Out:
#        creative_id  average_seconds_played      cost  \
# 28712       111412                2.448444 -3.493295
# 59867       114233                0.405465 -3.033186
# 1167        111503                2.448444 -3.347435
# 64004       114233                2.448444 -3.033186
# 1154        114348                1.386294 -3.347435
# 38595       111832                0.916291 -3.226812
# 99971       115408                2.448444 -3.226812
# 90912       113051                2.448444 -3.493295
# 26956        97826                1.299283 -3.267838
# 22227       112105                1.974081 -3.267838
# 9839        113292                2.448444 -3.061189
# 15816       106258                2.448444 -3.256982
# 82068       112272                2.448444 -3.493295
# 48330       115226                2.564949 -3.256982
# 3074        106115                2.448444 -3.423172
# 23152       100011                2.448444 -3.347435
# 91555       115250                2.448444 -2.740489
# 29204       113293                1.609438 -3.699715
# 82983       111762                2.448444 -3.053556
# 76641       112344                2.448444 -3.705236
# 57547       115179                2.448444 -3.617418
# 35091       114346                2.282382 -3.347435
# 39997       113293                2.448444 -3.443469
# 51119       115437                0.693147 -3.493295
# 69921       115245                1.134980 -3.443469
# 12154       115234                2.448444 -3.256982
# 38271       115222                2.407946 -2.794348
# 29745       112358                2.448444 -3.141814
# 46908       112898                2.448444 -3.226812
# 45204       112159                3.433987 -3.114935
# ...            ...                     ...       ...
# 99249        82016                2.448444 -3.226812
# 11247       113643                2.448444 -3.033186
# 9095        113292                2.448444 -3.617418
# 45260       114708                2.448444 -3.699715
# 36216       106818                2.448444 -3.347435
# 90885       115372                2.448444 -3.443469
# 81902       106258                2.448444 -3.256982
# 37968        93113                2.833213 -3.347435
# 52924       114849                2.448444 -3.256982
# 43497       112818                2.448444 -3.493295
# 44722       113047                2.944439 -3.443469
# 62134       112786                2.448444 -3.199940
# 4576        115378                2.448444 -3.736802
# 4365        113292                0.000000 -3.699715
# 89330       114374                1.609438 -3.699715
# 71941       114948                2.484907 -3.015454
# 89294       114945                0.916291 -2.867097
# 38805       113258                2.448444 -3.399080
# 86797       115465                2.448444 -3.226812
# 23265       107213                1.609438 -3.286333
# 35570       113582                1.866661 -3.347435
# 19173       109813                2.448444 -3.033186
# 39313       115021                2.448444 -3.347435
# 64247       113292                3.295837 -3.322270
# 89806       114312                2.448444 -3.736802
# 25004       113836                2.890372 -3.226812
# 32168       110021                2.448444 -2.849852
# 30290       114233                2.448444 -3.033186
# 13907       113601                2.448444 -3.347435
# 9887        112802                1.609438 -3.202631
#
#        user_operating_system iOS  user_operating_system Windows  \
# 28712                       True                          False
# 59867                       True                          False
# 1167                        True                          False
# 64004                       True                          False
# 1154                        True                          False
# 38595                      False                           True
# 99971                      False                           True
# 90912                      False                           True
# 26956                       True                          False
# 22227                       True                          False
# 9839                       False                           True
# 15816                      False                           True
# 82068                       True                          False
# 48330                       True                          False
# 3074                        True                          False
# 23152                      False                          False
# 91555                       True                          False
# 29204                      False                          False
# 82983                       True                          False
# 76641                      False                          False
# 57547                      False                          False
# 35091                       True                          False
# 39997                       True                          False
# 51119                      False                          False
# 69921                       True                          False
# 12154                      False                          False
# 38271                      False                          False
# 29745                       True                          False
# 46908                      False                           True
# 45204                      False                           True
# ...                          ...                            ...
# 99249                      False                           True
# 11247                       True                          False
# 9095                       False                           True
# 45260                      False                          False
# 36216                       True                          False
# 90885                       True                          False
# 81902                      False                           True
# 37968                      False                          False
# 52924                      False                           True
# 43497                       True                          False
# 44722                      False                          False
# 62134                      False                           True
# 4576                       False                          False
# 4365                       False                           True
# 89330                      False                           True
# 71941                      False                          False
# 89294                      False                           True
# 38805                      False                           True
# 86797                      False                           True
# 23265                       True                          False
# 35570                       True                          False
# 19173                       True                          False
# 39313                       True                          False
# 64247                      False                           True
# 89806                       True                          False
# 25004                      False                           True
# 32168                      False                           True
# 30290                       True                          False
# 13907                       True                          False
# 9887                       False                          False
#
#        user_operating_system Android  user_operating_system OS X  \
# 28712                          False                       False
# 59867                          False                       False
# 1167                           False                       False
# 64004                          False                       False
# 1154                           False                       False
# 38595                          False                       False
# 99971                          False                       False
# 90912                          False                       False
# 26956                          False                       False
# 22227                          False                       False
# 9839                           False                       False
# 15816                          False                       False
# 82068                          False                       False
# 48330                          False                       False
# 3074                           False                       False
# 23152                           True                       False
# 91555                          False                       False
# 29204                           True                       False
# 82983                          False                       False
# 76641                           True                       False
# 57547                           True                       False
# 35091                          False                       False
# 39997                          False                       False
# 51119                           True                       False
# 69921                          False                       False
# 12154                           True                       False
# 38271                          False                        True
# 29745                          False                       False
# 46908                          False                       False
# 45204                          False                       False
# ...                              ...                         ...
# 99249                          False                       False
# 11247                          False                       False
# 9095                           False                       False
# 45260                           True                       False
# 36216                          False                       False
# 90885                          False                       False
# 81902                          False                       False
# 37968                          False                       False
# 52924                          False                       False
# 43497                          False                       False
# 44722                           True                       False
# 62134                          False                       False
# 4576                            True                       False
# 4365                           False                       False
# 89330                          False                       False
# 71941                           True                       False
# 89294                          False                       False
# 38805                          False                       False
# 86797                          False                       False
# 23265                          False                       False
# 35570                          False                       False
# 19173                          False                       False
# 39313                          False                       False
# 64247                          False                       False
# 89806                          False                       False
# 25004                          False                       False
# 32168                          False                       False
# 30290                          False                       False
# 13907                          False                       False
# 9887                           False                       False
#
#        user_operating_system macOS  user_operating_system Linux  \
# 28712                        False                        False
# 59867                        False                        False
# 1167                         False                        False
# 64004                        False                        False
# 1154                         False                        False
# 38595                        False                        False
# 99971                        False                        False
# 90912                        False                        False
# 26956                        False                        False
# 22227                        False                        False
# 9839                         False                        False
# 15816                        False                        False
# 82068                        False                        False
# 48330                        False                        False
# 3074                         False                        False
# 23152                        False                        False
# 91555                        False                        False
# 29204                        False                        False
# 82983                        False                        False
# 76641                        False                        False
# 57547                        False                        False
# 35091                        False                        False
# 39997                        False                        False
# 51119                        False                        False
# 69921                        False                        False
# 12154                        False                        False
# 38271                        False                        False
# 29745                        False                        False
# 46908                        False                        False
# 45204                        False                        False
# ...                            ...                          ...
# 99249                        False                        False
# 11247                        False                        False
# 9095                         False                        False
# 45260                        False                        False
# 36216                        False                        False
# 90885                        False                        False
# 81902                        False                        False
# 37968                        False                        False
# 52924                        False                        False
# 43497                        False                        False
# 44722                        False                        False
# 62134                        False                        False
# 4576                         False                        False
# 4365                         False                        False
# 89330                        False                        False
# 71941                        False                        False
# 89294                        False                        False
# 38805                        False                        False
# 86797                        False                        False
# 23265                        False                        False
# 35570                        False                        False
# 19173                        False                        False
# 39313                        False                        False
# 64247                        False                        False
# 89806                        False                        False
# 25004                        False                        False
# 32168                        False                        False
# 30290                        False                        False
# 13907                        False                        False
# 9887                          True                        False
#
#        user_operating_system Chrome OS  user_operating_system Fire OS  \
# 28712                            False                          False
# 59867                            False                          False
# 1167                             False                          False
# 64004                            False                          False
# 1154                             False                          False
# 38595                            False                          False
# 99971                            False                          False
# 90912                            False                          False
# 26956                            False                          False
# 22227                            False                          False
# 9839                             False                          False
# 15816                            False                          False
# 82068                            False                          False
# 48330                            False                          False
# 3074                             False                          False
# 23152                            False                          False
# 91555                            False                          False
# 29204                            False                          False
# 82983                            False                          False
# 76641                            False                          False
# 57547                            False                          False
# 35091                            False                          False
# 39997                            False                          False
# 51119                            False                          False
# 69921                            False                          False
# 12154                            False                          False
# 38271                            False                          False
# 29745                            False                          False
# 46908                            False                          False
# 45204                            False                          False
# ...                                ...                            ...
# 99249                            False                          False
# 11247                            False                          False
# 9095                             False                          False
# 45260                            False                          False
# 36216                            False                          False
# 90885                            False                          False
# 81902                            False                          False
# 37968                            False                           True
# 52924                            False                          False
# 43497                            False                          False
# 44722                            False                          False
# 62134                            False                          False
# 4576                             False                          False
# 4365                             False                          False
# 89330                            False                          False
# 71941                            False                          False
# 89294                            False                          False
# 38805                            False                          False
# 86797                            False                          False
# 23265                            False                          False
# 35570                            False                          False
# 19173                            False                          False
# 39313                            False                          False
# 64247                            False                          False
# 89806                            False                          False
# 25004                            False                          False
# 32168                            False                          False
# 30290                            False                          False
# 13907                            False                          False
# 9887                             False                          False
#
#        user_operating_system BlackBerry OS  user_operating_system unknown  \
# 28712                                False                          False
# 59867                                False                          False
# 1167                                 False                          False
# 64004                                False                          False
# 1154                                 False                          False
# 38595                                False                          False
# 99971                                False                          False
# 90912                                False                          False
# 26956                                False                          False
# 22227                                False                          False
# 9839                                 False                          False
# 15816                                False                          False
# 82068                                False                          False
# 48330                                False                          False
# 3074                                 False                          False
# 23152                                False                          False
# 91555                                False                          False
# 29204                                False                          False
# 82983                                False                          False
# 76641                                False                          False
# 57547                                False                          False
# 35091                                False                          False
# 39997                                False                          False
# 51119                                False                          False
# 69921                                False                          False
# 12154                                False                          False
# 38271                                False                          False
# 29745                                False                          False
# 46908                                False                          False
# 45204                                False                          False
# ...                                    ...                            ...
# 99249                                False                          False
# 11247                                False                          False
# 9095                                 False                          False
# 45260                                False                          False
# 36216                                False                          False
# 90885                                False                          False
# 81902                                False                          False
# 37968                                False                          False
# 52924                                False                          False
# 43497                                False                          False
# 44722                                False                          False
# 62134                                False                          False
# 4576                                 False                          False
# 4365                                 False                          False
# 89330                                False                          False
# 71941                                False                          False
# 89294                                False                          False
# 38805                                False                          False
# 86797                                False                          False
# 23265                                False                          False
# 35570                                False                          False
# 19173                                False                          False
# 39313                                False                          False
# 64247                                False                          False
# 89806                                False                          False
# 25004                                False                          False
# 32168                                False                          False
# 30290                                False                          False
# 13907                                False                          False
# 9887                                 False                          False
#
#        user_operating_system RIM OS  user_device PersonalComputer  \
# 28712                         False                         False
# 59867                         False                         False
# 1167                          False                         False
# 64004                         False                         False
# 1154                          False                         False
# 38595                         False                          True
# 99971                         False                          True
# 90912                         False                          True
# 26956                         False                         False
# 22227                         False                         False
# 9839                          False                          True
# 15816                         False                          True
# 82068                         False                         False
# 48330                         False                         False
# 3074                          False                         False
# 23152                         False                         False
# 91555                         False                         False
# 29204                         False                         False
# 82983                         False                         False
# 76641                         False                         False
# 57547                         False                         False
# 35091                         False                         False
# 39997                         False                         False
# 51119                         False                         False
# 69921                         False                         False
# 12154                         False                         False
# 38271                         False                          True
# 29745                         False                         False
# 46908                         False                          True
# 45204                         False                          True
# ...                             ...                           ...
# 99249                         False                          True
# 11247                         False                         False
# 9095                          False                          True
# 45260                         False                         False
# 36216                         False                         False
# 90885                         False                         False
# 81902                         False                          True
# 37968                         False                         False
# 52924                         False                          True
# 43497                         False                         False
# 44722                         False                         False
# 62134                         False                          True
# 4576                          False                         False
# 4365                          False                          True
# 89330                         False                          True
# 71941                         False                         False
# 89294                         False                          True
# 38805                         False                          True
# 86797                         False                          True
# 23265                         False                         False
# 35570                         False                         False
# 19173                         False                         False
# 39313                         False                         False
# 64247                         False                          True
# 89806                         False                         False
# 25004                         False                          True
# 32168                         False                          True
# 30290                         False                         False
# 13907                         False                         False
# 9887                          False                          True
#
#        user_device Phone  user_device Tablet  user_device ConnectedTv
# 28712               True               False                    False
# 59867              False                True                    False
# 1167               False                True                    False
# 64004              False                True                    False
# 1154               False                True                    False
# 38595              False               False                    False
# 99971              False               False                    False
# 90912              False               False                    False
# 26956              False                True                    False
# 22227              False                True                    False
# 9839               False               False                    False
# 15816              False               False                    False
# 82068              False                True                    False
# 48330               True               False                    False
# 3074               False                True                    False
# 23152               True               False                    False
# 91555               True               False                    False
# 29204              False                True                    False
# 82983               True               False                    False
# 76641               True               False                    False
# 57547               True               False                    False
# 35091              False                True                    False
# 39997               True               False                    False
# 51119               True               False                    False
# 69921              False                True                    False
# 12154               True               False                    False
# 38271              False               False                    False
# 29745               True               False                    False
# 46908              False               False                    False
# 45204              False               False                    False
# ...                  ...                 ...                      ...
# 99249              False               False                    False
# 11247               True               False                    False
# 9095               False               False                    False
# 45260               True               False                    False
# 36216               True               False                    False
# 90885               True               False                    False
# 81902              False               False                    False
# 37968               True               False                    False
# 52924              False               False                    False
# 43497               True               False                    False
# 44722               True               False                    False
# 62134              False               False                    False
# 4576                True               False                    False
# 4365               False               False                    False
# 89330              False               False                    False
# 71941               True               False                    False
# 89294              False               False                    False
# 38805              False               False                    False
# 86797              False               False                    False
# 23265              False                True                    False
# 35570               True               False                    False
# 19173              False                True                    False
# 39313               True               False                    False
# 64247              False               False                    False
# 89806              False                True                    False
# 25004              False               False                    False
# 32168              False               False                    False
# 30290              False                True                    False
# 13907              False                True                    False
# 9887               False               False                    False
#
# [79993 rows x 18 columns]

# %% [markdown]
# Regarding the feature 'creative_id', we have a problem, since it is numerical, but only in disguise - it is actually categorical, with the numerical values not meaning anything.
#
# We could do several things:
#
# 1) We could use one hot encoding. This could provide us of a very good way of identifying the video. However, it also presents some problems:
#     - there are too many variables - 926 in the training set.
#     - what happens if we want to do this on other videos not in the list?
# 2) We could use this as a numerical feature. The problem is that there is no meaning in the number.
#
# 3) We could ignore the feature.
#
# A rigorous approach would compare the three options, but to make it brief, let's ignore it.

# %%
X_train = X_train.drop('creative_id', axis=1)

# %% [markdown]
# ##### Data Normalization
#
# Now we will standardize the data, as it is important for some machine learning algorithms like SVMs.

# %%
# Let's store the means and stds for the test data
numerical_features = ["average_seconds_played", "cost"]
means = X_train[numerical_features].mean()
std = X_train[numerical_features].std()

from sklearn import preprocessing

X_train[numerical_features]=preprocessing.scale(X_train[numerical_features])

print(X_train[numerical_features].mean())
print(X_train[numerical_features].std())
display(X_train.head())
# Out:
#        average_seconds_played      cost  user_operating_system iOS  \
# 28712                0.242895 -0.850578                       True
# 59867               -2.706592  1.272242                       True
# 1167                 0.242895 -0.177616                       True
# 64004                0.242895  1.272242                       True
# 1154                -1.290551 -0.177616                       True
#
#        user_operating_system Windows  user_operating_system Android  \
# 28712                          False                          False
# 59867                          False                          False
# 1167                           False                          False
# 64004                          False                          False
# 1154                           False                          False
#
#        user_operating_system OS X  user_operating_system macOS  \
# 28712                       False                        False
# 59867                       False                        False
# 1167                        False                        False
# 64004                       False                        False
# 1154                        False                        False
#
#        user_operating_system Linux  user_operating_system Chrome OS  \
# 28712                        False                            False
# 59867                        False                            False
# 1167                         False                            False
# 64004                        False                            False
# 1154                         False                            False
#
#        user_operating_system Fire OS  user_operating_system BlackBerry OS  \
# 28712                          False                                False
# 59867                          False                                False
# 1167                           False                                False
# 64004                          False                                False
# 1154                           False                                False
#
#        user_operating_system unknown  user_operating_system RIM OS  \
# 28712                          False                         False
# 59867                          False                         False
# 1167                           False                         False
# 64004                          False                         False
# 1154                           False                         False
#
#        user_device PersonalComputer  user_device Phone  user_device Tablet  \
# 28712                         False               True               False
# 59867                         False              False                True
# 1167                          False              False                True
# 64004                         False              False                True
# 1154                          False              False                True
#
#        user_device ConnectedTv
# 28712                    False
# 59867                    False
# 1167                     False
# 64004                    False
# 1154                     False

# %% [markdown]
# ##### Feature Selection
#
# Regarding feature selection, random forests produce a good indicator of which ones are best. In this case we will do it only for the 17 already-existing features, but we should do it for any generated features too.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# Build a forest and compute the feature importances
forest = RandomForestRegressor(n_estimators=50)
forest.fit(X_train, y_train["revenue"])

importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor

# Build a forest and compute the feature importances
forest = RandomForestRegressor(n_estimators=50)

forest.fit(X_train, y_train)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))

# Plot the feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
       color="r", yerr=std[indices], align="center")
plt.xticks(range(X.shape[1]), indices)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %%
Feature scaling

3) Statistical Transformations: Same reason as above, we could try to reduce the skewness using transformations like log-

# %%
from sklearn import svm

X = [[0, 0], [2, 2]]
y = [0.5, 2.5]
clf = svm.SVR()
clf.fit(X, y) 


clf.predict([[1, 1]])

# %% [markdown]
# Since we don't have another dataset, let's use the given dataset as a proxy for the new dataset - although, of course, we will use the revenue not as a feature but as a label.
#
# Use an SVR and ensemble regressors
# Feature selection? Evidently, no creative id
#
# Cross Validation
